# %% [markdown]
# # Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Dataframes

# %% [markdown]
# #### Create a path variable

# %%
path = r'C:\Users\Aaron\CareerFoundry\Instacart Basket Analysis'

# %% [markdown]
# ##### Import ords_prods_merged.pkl

# %%
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Checking new df_ords_prods_merged
df_ords_prods_merged.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0  2539329.0      1.0           1.0                 2.0         8.0
# 1  2398795.0      1.0           2.0                 3.0         7.0
# 2   473747.0      1.0           3.0                 3.0        12.0
# 3  2254736.0      1.0           4.0                 4.0         7.0
# 4   431534.0      1.0           5.0                 4.0        15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    11.0         196                1.0        0.0   both
# 1                    15.0         196                1.0        1.0   both
# 2                    21.0         196                1.0        1.0   both
# 3                    29.0         196                1.0        1.0   both
# 4                    28.0         196                1.0        1.0   both
#
#   product_name  aisle_id  department_id  prices
# 0         Soda      77.0            7.0     9.0
# ...

# %% [markdown]
# ##### Creating a subset of the ords_prods_merged

# %%
# Subset of the first one million rows
df_ords_prods_merge_subset = df_ords_prods_merged[:1000000]

# %%
# Checking the shape of the new subset
df_ords_prods_merge_subset.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # Creating price_label column via user-defined functions

# %%
def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else: return 'Not enough data'

# %%
# Using the price_label function on our dataframe
df_ords_prods_merge_subset['price_range'] = df_ords_prods_merge_subset.apply(price_label, axis = 1)
# Out:
# <ipython-input-18-6c54c876c127>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merge_subset['price_range'] = df_ords_prods_merge_subset.apply(price_label, axis = 1)

# %%
df_ords_prods_merge_subset['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Checking the most expensive product within the subset
df_ords_prods_merge_subset['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ### if statements with loc() function

# %%
df_ords_prods_merge_subset.loc[df_ords_prods_merge_subset['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Aaron\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_ords_prods_merge_subset.loc[(df_ords_prods_merge_subset['prices'] <= 15) & (df_ords_prods_merge_subset['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\Aaron\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_ords_prods_merge_subset.loc[df_ords_prods_merge_subset['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\Aaron\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_ords_prods_merge_subset['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### Using loc() on entire dataframe
# ##### We can use loc() on the entire dataframe (as opposed to using the user-defined function on only a subset)

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860868
# Low-range product     10126324
# High-range product      417678
# NaN                      30200
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## if-statements with for-loops

# %%
# Printing the frequency of 'orders_day_of_week'
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    6209808
# 1.0    5665951
# 6.0    4500391
# 2.0    4217868
# 5.0    4209603
# 3.0    3844175
# 4.0    3787263
# NaN         11
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# ##### Finding out which days are the busiest and which ones are the slowest

# %%
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Creating a new column in our df_ords_prods_merged consisting of our results
df_ords_prods_merged['busiest_day'] = result

# %%
# Counting the values in our new column
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437999
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Start of Task 4.7 Assignment

# %% [markdown]
# ### 2)

# %%
# Creating a for loop that appends to days that reflects 2 busy and 2 slowest days
days = []

for day in df_ords_prods_merged["orders_day_of_week"]:
    if day == 0 or day == 1:
        days.append("Busiest days")
    elif day == 4 or day == 3:
        days.append("Slowest days")
    else:
        days.append("Regularly busy")

# %%
# Creating a new column for busiest_days column
df_ords_prods_merged['busiest_days'] = days

# %%
# Checking the values of the newly updated busiest_days column
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12927873
# Busiest days      11875759
# Slowest days       7631438
# Name: busiest_days, dtype: int64

# %% [markdown]
# ### 3)

# %%
# Check the output of new column
df_ords_prods_merged[['orders_day_of_week','busiest_days']].head(50)
# Out:
#     orders_day_of_week    busiest_days
# 0                  2.0  Regularly busy
# 1                  3.0    Slowest days
# 2                  3.0    Slowest days
# 3                  4.0    Slowest days
# 4                  4.0    Slowest days
# 5                  2.0  Regularly busy
# 6                  1.0    Busiest days
# 7                  1.0    Busiest days
# 8                  1.0    Busiest days
# 9                  4.0    Slowest days
# 10                 1.0    Busiest days
# 11                 2.0  Regularly busy
# 12                 2.0  Regularly busy
# 13                 1.0    Busiest days
# 14                 1.0    Busiest days
# 15                 5.0  Regularly busy
# 16                 6.0  Regularly busy
# 17                 4.0    Slowest days
# 18                 3.0    Slowest days
# 19                 3.0    Slowest days
# 20                 3.0    Slowest days
# 21                 4.0    Slowest days
# 22                 4.0    Slowest days
# ...

# %%
# Checking the columns values
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12927873
# Busiest days      11875759
# Slowest days       7631438
# Name: busiest_days, dtype: int64

# %%
# Checking the shape of our table
df_ords_prods_merged.shape
# Out:
# (32435070, 17)

# %% [markdown]
# ### 4)

# %%
# Checking the count of orders in each hour
df_ords_prods_merged['order_time'].value_counts(dropna = False)
# Out:
# 10.0    2764476
# 11.0    2738647
# 14.0    2691598
# 15.0    2664583
# 13.0    2663346
# 12.0    2620898
# 16.0    2537506
# 9.0     2456751
# 17.0    2089510
# 8.0     1719991
# 18.0    1637956
# 19.0    1259416
# 20.0     977049
# 7.0      891951
# 21.0     796379
# 22.0     634743
# 23.0     402621
# 6.0      290796
# 0.0      218951
# 1.0      115787
# 5.0       88064
# 2.0       69435
# 4.0       53284
# 3.0       51321
# NaN          11
# Name: order_time, dtype: int64

# %% [markdown]
# The top 5 busiest hours are:
# 1) 10 AM
#
# 2) 11 AM
#
# 3) 2 PM
#
# 4) 3 PM
#
# 5) 1 PM

# %%
# Creating a for loop that appends to hours that reflects Most orders, Average orders, and Fewest orders
hours = []

for hour in df_ords_prods_merged["order_time"]:
    if hour == 9 or hour == 10 or hour == 11 or hour == 12 or hour == 13 or hour == 14 or hour == 15 or hour == 16:
        hours.append("Most orders")
    elif hour == 17 or hour == 8 or hour == 18 or hour == 19 or hour == 20 or hour == 7 or hour == 21 or hour == 22:
        hours.append("Average orders")
    else:
        hours.append("Fewest orders")

# %%
# Creating a new column for the busiest period of day
df_ords_prods_merged['busiest_period_of_day'] = hours

# %%
# Checking the df for all the columns
df_ords_prods_merged.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0  2539329.0      1.0           1.0                 2.0         8.0
# 1  2398795.0      1.0           2.0                 3.0         7.0
# 2   473747.0      1.0           3.0                 3.0        12.0
# 3  2254736.0      1.0           4.0                 4.0         7.0
# 4   431534.0      1.0           5.0                 4.0        15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    11.0         196                1.0        0.0   both
# 1                    15.0         196                1.0        1.0   both
# 2                    21.0         196                1.0        1.0   both
# 3                    29.0         196                1.0        1.0   both
# 4                    28.0         196                1.0        1.0   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# ### 5)

# %%
# Check the frequency of the new busiest period of day column
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21137805
# Average orders    10006995
# Fewest orders      1290270
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ### 7)

# %%
# Export file as pickle file into Prepared Data folder
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_UPDATED.pkl'))
